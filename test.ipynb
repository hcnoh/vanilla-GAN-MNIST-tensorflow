# %%
import pickle

import numpy as np
import matplotlib.pyplot as plt

from data.mnist import Mnist

# %%
loader = Mnist()

# %%
loader.train_labels.shape
# Out:
# (60000,)

# %%
plt.imshow(np.reshape(loader.train_features[0], newshape=[28, 28]))

# %%
with open("../../learned-models/vanilla-gan/vanilla-GAN/vanilla-GAN-results.pickle", "rb") as f:
    _, _, gs = pickle.load(f)

print(len(gs) * 100)
for g in gs:
    plt.imshow(np.reshape(g, newshape=[28, 28]))
    plt.show()
# Out:
# 10000
